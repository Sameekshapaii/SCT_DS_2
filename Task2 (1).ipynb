# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("abalone.csv")
df.head()
# Out:
#    id sex  length  diameter  height  whole_wight  shucked_width  \
# 0   1   M   0.455     0.365   0.095       0.5140         0.2245
# 1   2   M   0.350     0.265   0.090       0.2255         0.0995
# 2   3   F   0.530     0.420   0.135       0.6770         0.2565
# 3   4   M   0.440     0.365   0.125       0.5160         0.2155
# 4   5   I   0.330     0.255   0.080       0.2050         0.0895
#
#    viscera_width  shell_width  class_rings
# 0         0.1010        0.150         15.0
# 1         0.0485        0.070          7.0
# 2         0.1415        0.210          9.0
# 3         0.1140        0.155         10.0
# 4         0.0395        0.055          7.0

# %%
df.columns
# Out:
# Index(['id', 'sex', 'length', 'diameter', 'height', 'whole_wight',
#        'shucked_width', 'viscera_width', 'shell_width', 'class_rings'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id               0
# sex              1
# length           1
# diameter         1
# height           1
# whole_wight      1
# shucked_width    1
# viscera_width    1
# shell_width      1
# class_rings      1
# dtype: int64

# %%
df.rename(columns={
    'Whole weight.1': 'Shucked_weight',
    'Whole weight.2': 'Viscera_weight'
}, inplace=True)

# %%
print(df.columns)
sns.countplot(x='sex', data=df)
plt.title("Distribution of Abalone by Sex")
plt.show()
# Out:
# Index(['id', 'sex', 'length', 'diameter', 'height', 'whole_wight',
#        'shucked_width', 'viscera_width', 'shell_width', 'class_rings'],
#       dtype='object')

# %%
# Convert all column names to lowercase and remove spaces
df.columns = df.columns.str.lower().str.replace(' ', '_')

# Now 'Rings' becomes 'rings'
sns.histplot(df['class_rings'], bins=30, kde=True)
plt.title("Distribution of Rings (Age)")
plt.show()

# %%
sns.boxplot(x='sex', y='class_rings', data=df)
plt.title("rings by sex")
plt.show()

# %%
# Filter only numeric columns for correlation
numeric_df = df.select_dtypes(include=['float64', 'int64'])

plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
